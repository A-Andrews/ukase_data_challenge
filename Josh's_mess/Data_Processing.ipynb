# %%
import pandas as pd

# %%
data = pd.read_csv('../../data/zoonosis_dataset_full.csv')
info = pd.read_csv('../../data/allflu_wgs_ref.csv')

# %%
data.shape
# Out:
# (19531, 964)

# %%
data_full = info.merge(data, how = "outer", on = 'gid')
data_full.head()
# Out:
#    Unnamed: 0                                               gid  \
# 0         619   A/Accipiter_gentilis_schvedowi/Tianjin/22/2017M
# 1         620               A/African_Stonechat/Vietnam/8/2009A
# 2         621  A/Alopochen_aegyptiacus/Belgium/1570_B6613/2017M
# 3         622  A/Alopochen_aegyptiacus/Belgium/3237_B6659/2017M
# 4         623  A/Alopochen_aegyptiacus/Belgium/3237_B6663/2017M
#
#                                              title subtype_x label_x src_x  \
# 0   A/Accipiter_gentilis_schvedowi/Tianjin/22/2017      H9N2      nz  NCBI
# 1               A/African_Stonechat/Vietnam/8/2009      H9N2      nz  NCBI
# 2  A/Alopochen_aegyptiacus/Belgium/1570_B6613/2017      H1N2      nz  NCBI
# 3  A/Alopochen_aegyptiacus/Belgium/3237_B6659/2017      H1N2      nz  NCBI
# 4  A/Alopochen_aegyptiacus/Belgium/3237_B6663/2017      H1N2      nz  NCBI
#
#          date subtype_y label_y src_y  ...  PAAC_Xc1.L_PB2  PAAC_Xc1.A_PB2  \
# ...

# %%
data_full = data_full.drop(["Unnamed: 0","subtype_x", "label_x", "src_x"], axis=1)
data_full.head()
# Out:
#                                                 gid  \
# 0   A/Accipiter_gentilis_schvedowi/Tianjin/22/2017M
# 1               A/African_Stonechat/Vietnam/8/2009A
# 2  A/Alopochen_aegyptiacus/Belgium/1570_B6613/2017M
# 3  A/Alopochen_aegyptiacus/Belgium/3237_B6659/2017M
# 4  A/Alopochen_aegyptiacus/Belgium/3237_B6663/2017M
#
#                                              title        date subtype_y  \
# 0   A/Accipiter_gentilis_schvedowi/Tianjin/22/2017  2017-06-15      H9N2
# 1               A/African_Stonechat/Vietnam/8/2009  2009-11-15      H9N2
# 2  A/Alopochen_aegyptiacus/Belgium/1570_B6613/2017  2017-02-16      H1N2
# 3  A/Alopochen_aegyptiacus/Belgium/3237_B6659/2017  2017-03-25      H1N2
# 4  A/Alopochen_aegyptiacus/Belgium/3237_B6663/2017  2017-03-25      H1N2
#
#   label_y src_y  TT_p2_Bias_HA  V_aa_Bias_HA  GGC_Bias_HA  AG_Bias_HA  ...  \
# 0      nz  NCBI       0.866878      0.055258     0.372093    0.937347  ...
# ...

# %%
data_full.shape
# Out:
# (19531, 966)

# %%
df_new = pd.DataFrame.copy(data_full)

# %%
df_new['b'] = 0 
col = df_new.columns.tolist()
col.insert(0, col.pop()) #loc is the column's index you want to insert into
df_new = df_new[col]
df_new['a'] = 0 
col = df_new.columns.tolist()
col.insert(0, col.pop()) #loc is the column's index you want to insert into
df_new = df_new[col]
df_new['Year'] = 0 
col = df_new.columns.tolist()
col.insert(0, col.pop()) #loc is the column's index you want to insert into
df_new = df_new[col]
df_new['Code'] = 0 
col = df_new.columns.tolist()
col.insert(0, col.pop()) #loc is the column's index you want to insert into
df_new = df_new[col]
df_new['Location'] = 0 
col = df_new.columns.tolist()
col.insert(0, col.pop()) #loc is the column's index you want to insert into
df_new = df_new[col]
df_new['Species'] = 0 
col = df_new.columns.tolist()
col.insert(0, col.pop()) #loc is the column's index you want to insert into
df_new = df_new[col]
df_new['Blank'] = 0 
col = df_new.columns.tolist()
col.insert(0, col.pop()) #loc is the column's index you want to insert into
df_new = df_new[col]

# %%
splits = df_new['title'].str.split('/', expand=True)
df_new[['Blank', 'Species', 'Location', 'Code', 'Year', 'a', 'b']] = splits
df_new['Year'] = df_new.Year.str[:-1]
df_new.head()
# Out:
#   Blank                       Species Location        Code Year     a     b  \
# 0     A  Accipiter_gentilis_schvedowi  Tianjin          22  201  None  None
# 1     A             African_Stonechat  Vietnam           8  200  None  None
# 2     A         Alopochen_aegyptiacus  Belgium  1570_B6613  201  None  None
# 3     A         Alopochen_aegyptiacus  Belgium  3237_B6659  201  None  None
# 4     A         Alopochen_aegyptiacus  Belgium  3237_B6663  201  None  None
#
#                                                 gid  \
# 0   A/Accipiter_gentilis_schvedowi/Tianjin/22/2017M
# 1               A/African_Stonechat/Vietnam/8/2009A
# 2  A/Alopochen_aegyptiacus/Belgium/1570_B6613/2017M
# 3  A/Alopochen_aegyptiacus/Belgium/3237_B6659/2017M
# 4  A/Alopochen_aegyptiacus/Belgium/3237_B6663/2017M
#
#                                              title        date  ...  \
# 0   A/Accipiter_gentilis_schvedowi/Tianjin/22/2017  2017-06-15  ...
# ...

# %%
df_new = df_new.drop(['Blank', 'Code', 'Year', 'a', 'b'], axis=1)

# %%
df_new.head()
# Out:
#                         Species Location  \
# 0  Accipiter_gentilis_schvedowi  Tianjin
# 1             African_Stonechat  Vietnam
# 2         Alopochen_aegyptiacus  Belgium
# 3         Alopochen_aegyptiacus  Belgium
# 4         Alopochen_aegyptiacus  Belgium
#
#                                                 gid  \
# 0   A/Accipiter_gentilis_schvedowi/Tianjin/22/2017M
# 1               A/African_Stonechat/Vietnam/8/2009A
# 2  A/Alopochen_aegyptiacus/Belgium/1570_B6613/2017M
# 3  A/Alopochen_aegyptiacus/Belgium/3237_B6659/2017M
# 4  A/Alopochen_aegyptiacus/Belgium/3237_B6663/2017M
#
#                                              title        date subtype_y  \
# 0   A/Accipiter_gentilis_schvedowi/Tianjin/22/2017  2017-06-15      H9N2
# 1               A/African_Stonechat/Vietnam/8/2009  2009-11-15      H9N2
# 2  A/Alopochen_aegyptiacus/Belgium/1570_B6613/2017  2017-02-16      H1N2
# 3  A/Alopochen_aegyptiacus/Belgium/3237_B6659/2017  2017-03-25      H1N2
# ...

# %%
df_new['Species'] = df_new['Species'].str.lower()

# %%
counts = df_new['Species'].value_counts()

# %%
print(counts)
# Out:
# Species
# chicken             4243
# mallard             3353
# duck                2655
# ruddy_turnstone     1342
# blue-winged_teal     743
#                     ...
# eastern_buzzard        1
# eider                  1
# fighting_bird          1
# finch                  1
# ngan                   1
# Name: count, Length: 464, dtype: int64

# %%
df_new['label_y'].value_counts()
# Out:
# label_y
# nz       18913
# hzoon      618
# Name: count, dtype: int64

# %%
df_temp = pd.DataFrame.copy(df_new)

# %%
df_temp.loc[df_temp.label_y=='hzoon', 'Location'] = df_temp.loc[df_temp.label_y=='hzoon', 'Species']
df_temp.loc[df_temp.label_y=='hzoon', 'Species'] = ''

# %%
df_temp.head()

# %%
df_new.loc[df_new.label_y=='hzoon', 'Location'] = df_new.loc[df_new.label_y=='hzoon', 'Species']
df_new.loc[df_new.label_y=='hzoon', 'Species'] = 'human'

# %%
df_new['Species'] = df_new['Species'].str.lower()

# %%
counts = df_new['Species'].value_counts()
print(counts)
# Out:
# Species
# chicken             4243
# mallard             3353
# duck                2655
# ruddy_turnstone     1342
# blue-winged_teal     743
#                     ...
# fighting_bird          1
# finch                  1
# fowl                   1
# gray_headed_gull       1
# ngan                   1
# Name: count, Length: 402, dtype: int64

# %%
anas_platyrhynchos

# %%
df_temp

# %%
df_temp.loc[df_temp['Species'].str.contains('mallard', na=False), 'Species'] = 'mallard'
df_temp.loc[df_temp['Species'].str.contains('mulard', na=False), 'Species'] = 'mallard'
df_temp.loc[df_temp['Species'].str.contains('anas_platyrhynchos', na=False), 'Species'] = 'mallard'
counts_temp = df_temp['Species'].value_counts()
print(counts_temp)
# Out:
# Species
# chicken             4243
# mallard             3799
# duck                2655
# ruddy_turnstone     1342
# blue-winged_teal     743
#                     ...
# finch                  1
# fowl                   1
# gray_headed_gull       1
# gray_plover            1
# ngan                   1
# Name: count, Length: 392, dtype: int64

# %%
df_new.loc[df_new['Species'].str.contains('mallard', na=False), 'Species'] = 'mallard'
df_new.loc[df_new['Species'].str.contains('mulard', na=False), 'Species'] = 'mallard'
df_new.loc[df_new['Species'].str.contains('anas_platyrhynchos', na=False), 'Species'] = 'mallard'
counts_temp = df_new['Species'].value_counts()
print(counts_temp)
# Out:
# Species
# chicken             4243
# mallard             3799
# duck                2655
# ruddy_turnstone     1342
# blue-winged_teal     743
#                     ...
# finch                  1
# fowl                   1
# gray_headed_gull       1
# gray_plover            1
# ngan                   1
# Name: count, Length: 392, dtype: int64

# %%
df_new['SpeciesBins'] = df_new['Species']

# %%
df_new.loc[df_new['SpeciesBins'].str.contains('duck', na=False), 'SpeciesBins'] = 'duck'
df_new.loc[df_new['SpeciesBins'].str.contains('teal', na=False), 'SpeciesBins'] = 'teal'
df_new.loc[df_new['SpeciesBins'].str.contains('gull', na=False), 'SpeciesBins'] = 'gull'
df_new.loc[df_new['SpeciesBins'].str.contains('goose', na=False), 'SpeciesBins'] = 'goose'
df_new.loc[df_new['SpeciesBins'].str.contains('swan', na=False), 'SpeciesBins'] = 'swan'
df_new.loc[df_new['SpeciesBins'].str.contains('chicken', na=False), 'SpeciesBins'] = 'chicken'
df_new.loc[df_new['SpeciesBins'].str.contains('widgeon', na=False), 'SpeciesBins'] = 'wigeon'
df_new.loc[df_new['SpeciesBins'].str.contains('wigeon', na=False), 'SpeciesBins'] = 'wigeon'
df_new.loc[df_new['SpeciesBins'].str.contains('chiken', na=False), 'SpeciesBins'] = 'chicken'
df_new.loc[df_new['SpeciesBins'].str.contains('sandpiper', na=False), 'SpeciesBins'] = 'sandpiper'
df_new.loc[df_new['SpeciesBins'].str.contains('heron', na=False), 'SpeciesBins'] = 'heron'
df_new.loc[df_new['SpeciesBins'].str.contains('crane', na=False), 'SpeciesBins'] = 'crane'
df_new.loc[df_new['SpeciesBins'].str.contains('_owl', na=False), 'SpeciesBins'] = 'owl'
df_new.loc[df_new['SpeciesBins'].str.contains('quail', na=False), 'SpeciesBins'] = 'quail'
df_new.loc[df_new['SpeciesBins'].str.contains('hawk', na=False), 'SpeciesBins'] = 'hawk'
df_new.loc[df_new['SpeciesBins'].str.contains('eagle', na=False), 'SpeciesBins'] = 'eagle'
df_new.loc[df_new['SpeciesBins'].str.contains('stint', na=False), 'SpeciesBins'] = 'stint'
df_new.loc[df_new['SpeciesBins'].str.contains('swallow', na=False), 'SpeciesBins'] = 'swallow'
df_new.loc[df_new['SpeciesBins'].str.contains('tern', na=False), 'SpeciesBins'] = 'tern'
df_new.loc[df_new['SpeciesBins'].str.contains('falcon', na=False), 'SpeciesBins'] = 'falcon'
df_new.loc[df_new['SpeciesBins'].str.contains('pochard', na=False), 'SpeciesBins'] = 'pochard'
df_new.loc[df_new['SpeciesBins'].str.contains('sparrow', na=False), 'SpeciesBins'] = 'sparrow'
df_new.loc[df_new['SpeciesBins'].str.contains('stork', na=False), 'SpeciesBins'] = 'stork'
df_new.loc[df_new['SpeciesBins'].str.contains('oystercatcher', na=False), 'SpeciesBins'] = 'oystercatcher'
df_new.loc[df_new['SpeciesBins'].str.contains('pelican', na=False), 'SpeciesBins'] = 'pelican'
df_new.loc[df_new['SpeciesBins'].str.contains('buzzard', na=False), 'SpeciesBins'] = 'buzzard'
counts_temp_bins = df_new['SpeciesBins'].value_counts()
counts_temp_bins
# Out:
# SpeciesBins
# chicken              4323
# mallard              3799
# duck                 3527
# teal                 1445
# ruddy_turnstone      1342
#                      ...
# chukka                  1
# cape_shoveler           1
# african_stonechat       1
# brambling               1
# ngan                    1
# Name: count, Length: 192, dtype: int64

# %%
df_new.head()
# Out:
#                         Species Location  \
# 0  accipiter_gentilis_schvedowi  Tianjin
# 1             african_stonechat  Vietnam
# 2         alopochen_aegyptiacus  Belgium
# 3         alopochen_aegyptiacus  Belgium
# 4         alopochen_aegyptiacus  Belgium
#
#                                                 gid  \
# 0   A/Accipiter_gentilis_schvedowi/Tianjin/22/2017M
# 1               A/African_Stonechat/Vietnam/8/2009A
# 2  A/Alopochen_aegyptiacus/Belgium/1570_B6613/2017M
# 3  A/Alopochen_aegyptiacus/Belgium/3237_B6659/2017M
# 4  A/Alopochen_aegyptiacus/Belgium/3237_B6663/2017M
#
#                                              title        date subtype_y  \
# 0   A/Accipiter_gentilis_schvedowi/Tianjin/22/2017  2017-06-15      H9N2
# 1               A/African_Stonechat/Vietnam/8/2009  2009-11-15      H9N2
# 2  A/Alopochen_aegyptiacus/Belgium/1570_B6613/2017  2017-02-16      H1N2
# 3  A/Alopochen_aegyptiacus/Belgium/3237_B6659/2017  2017-03-25      H1N2
# ...

# %%
df_new= df_new.rename(columns={'subtype_y': 'subtype', 'label_y': 'label', 'src_y': 'src'})
df_new.head()
# Out:
#                         Species Location  \
# 0  accipiter_gentilis_schvedowi  Tianjin
# 1             african_stonechat  Vietnam
# 2         alopochen_aegyptiacus  Belgium
# 3         alopochen_aegyptiacus  Belgium
# 4         alopochen_aegyptiacus  Belgium
#
#                                                 gid  \
# 0   A/Accipiter_gentilis_schvedowi/Tianjin/22/2017M
# 1               A/African_Stonechat/Vietnam/8/2009A
# 2  A/Alopochen_aegyptiacus/Belgium/1570_B6613/2017M
# 3  A/Alopochen_aegyptiacus/Belgium/3237_B6659/2017M
# 4  A/Alopochen_aegyptiacus/Belgium/3237_B6663/2017M
#
#                                              title        date subtype label  \
# 0   A/Accipiter_gentilis_schvedowi/Tianjin/22/2017  2017-06-15    H9N2    nz
# 1               A/African_Stonechat/Vietnam/8/2009  2009-11-15    H9N2    nz
# 2  A/Alopochen_aegyptiacus/Belgium/1570_B6613/2017  2017-02-16    H1N2    nz
# 3  A/Alopochen_aegyptiacus/Belgium/3237_B6659/2017  2017-03-25    H1N2    nz
# ...

# %%
df_new.to_csv('full_data_with_species_and_locations.csv')
