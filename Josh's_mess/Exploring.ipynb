# %%
import pandas as pd

# %%
data = pd.read_csv('../data/zoonosis_dataset_full.csv')

# %%
df_zoo = pd.DataFrame.copy(data[data['label']=='hzoon'])
df_nz = pd.DataFrame.copy(data[data['label']=='nz'])

# %%
df_nz['gid'].filter(like='/', axis=0)
# Out:
# Series([], Name: gid, dtype: object)

# %%
df_nz_new = df_nz[df_nz['gid'].str.contains('/')]

# %%
df_zoo[['Blank', 'Location', 'Code', 'Year']] = df_zoo['gid'].str.split('/', expand=True)
df_zoo['Year'] = df_zoo.Year.str[:-1]
df_zoo.head()
# Out:
#                        gid subtype  label   src  TT_p2_Bias_HA  V_aa_Bias_HA  \
# 0  A/Anhui/1-DEWH730/2013C    H7N9  hzoon  NCBI       0.846074      0.057041
# 1          A/Anhui/1/2005H    H5N1  hzoon  NCBI       0.989385      0.058201
# 2          A/Anhui/2/2005H    H5N1  hzoon  NCBI       1.004523      0.056338
# 3  A/Anhui/DEWH72-01/2013C    H7N9  hzoon  NCBI       0.846074      0.057041
# 4  A/Anhui/DEWH72-02/2013C    H7N9  hzoon  NCBI       0.846074      0.057041
#
#    GGC_Bias_HA  AG_Bias_HA  CT_Bias_HA  ATA_Bias_HA  ...  PAAC_Xc1.F_PB2  \
# 0         0.48    0.957735    1.146911     1.255814  ...             0.0
# 1         0.00    0.936643    1.136000     1.390244  ...             0.0
# 2         0.00    0.965125    1.138024     1.390244  ...             0.0
# 3         0.48    0.957735    1.146911     1.255814  ...             0.0
# 4         0.48    0.958436    1.146911     1.255814  ...             0.0
#
# ...

# %%
df_nz.head()

# %%
df_nz.sort_values('gid')
splits = df_nz_new['gid'].str.split('/', expand=True)
# print(splits)
# splits = splits.loc[len(splits)==5]

df_nz_new[['Blank', 'Species', 'Location', 'Code', 'Year', 'a', 'b']] = splits
df_nz_new['Year'] = df_nz_new.Year.str[:-1]
df_nz_new.head()
# Out:
#     Blank                       Species Location        Code  Year     a  \
# 618     A  Accipiter_gentilis_schvedowi  Tianjin          22  2017  None
# 619     A             African_Stonechat  Vietnam           8  2009  None
# 620     A         Alopochen_aegyptiacus  Belgium  1570_B6613  2017  None
# 621     A         Alopochen_aegyptiacus  Belgium  3237_B6659  2017  None
# 622     A         Alopochen_aegyptiacus  Belgium  3237_B6663  2017  None
#
#         b                                               gid subtype label  \
# 618  None   A/Accipiter_gentilis_schvedowi/Tianjin/22/2017M    H9N2    nz
# 619  None               A/African_Stonechat/Vietnam/8/2009A    H9N2    nz
# 620  None  A/Alopochen_aegyptiacus/Belgium/1570_B6613/2017M    H1N2    nz
# 621  None  A/Alopochen_aegyptiacus/Belgium/3237_B6659/2017M    H1N2    nz
# 622  None  A/Alopochen_aegyptiacus/Belgium/3237_B6663/2017M    H1N2    nz
#
#      ... PAAC_Xc1.L_PB2  PAAC_Xc1.A_PB2  PAAC_Xc1.P_PB2  PAAC_Xc2.lambda3_PB2  \
# ...

# %%
df_nz_new['b'] = 0 
col = df_nz_new.columns.tolist()
col.insert(0, col.pop()) #loc is the column's index you want to insert into
df_nz_new = df_nz_new[col]
df_nz_new['a'] = 0 
col = df_nz_new.columns.tolist()
col.insert(0, col.pop()) #loc is the column's index you want to insert into
df_nz_new = df_nz_new[col]
df_nz_new['Year'] = 0 
col = df_nz_new.columns.tolist()
col.insert(0, col.pop()) #loc is the column's index you want to insert into
df_nz_new = df_nz_new[col]
df_nz_new['Code'] = 0 
col = df_nz_new.columns.tolist()
col.insert(0, col.pop()) #loc is the column's index you want to insert into
df_nz_new = df_nz_new[col]
df_nz_new['Location'] = 0 
col = df_nz_new.columns.tolist()
col.insert(0, col.pop()) #loc is the column's index you want to insert into
df_nz_new = df_nz_new[col]
df_nz_new['Species'] = 0 
col = df_nz_new.columns.tolist()
col.insert(0, col.pop()) #loc is the column's index you want to insert into
df_nz_new = df_nz_new[col]
df_nz_new['Blank'] = 0 
col = df_nz_new.columns.tolist()
col.insert(0, col.pop()) #loc is the column's index you want to insert into
df_nz_new = df_nz_new[col]
# Out:
# /var/folders/xy/wvlsxjjn1px0ql5dll2npm300000gs/T/ipykernel_23536/697134420.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nz_new['b'] = 0

# %%
df_nz_new.head()

# %%
df_nz_new['b'].value_counts()
# Out:
# b
# 2017M    1
# Name: count, dtype: int64

# %%
df_ordered = df_nz_new.sort_values(by=['b'])
df_ordered.head()
# Out:
#      Blank                       Species Location        Code  Year     a  \
# 4478     A                       chicken  Jiangsu          JS     0    71
# 618      A  Accipiter_gentilis_schvedowi  Tianjin          22  2017  None
# 619      A             African_Stonechat  Vietnam           8  2009  None
# 620      A         Alopochen_aegyptiacus  Belgium  1570_B6613  2017  None
# 621      A         Alopochen_aegyptiacus  Belgium  3237_B6659  2017  None
#
#           b                                               gid subtype label  \
# 4478  2017M                  A/chicken/Jiangsu/JS/02/71/2017M    H7N9    nz
# 618    None   A/Accipiter_gentilis_schvedowi/Tianjin/22/2017M    H9N2    nz
# 619    None               A/African_Stonechat/Vietnam/8/2009A    H9N2    nz
# 620    None  A/Alopochen_aegyptiacus/Belgium/1570_B6613/2017M    H1N2    nz
# 621    None  A/Alopochen_aegyptiacus/Belgium/3237_B6659/2017M    H1N2    nz
#
#       ... PAAC_Xc1.L_PB2  PAAC_Xc1.A_PB2  PAAC_Xc1.P_PB2  \
# ...

# %%
df_ordered['Year'][4478] = 2017
df_ordered.head()
# Out:
# /var/folders/xy/wvlsxjjn1px0ql5dll2npm300000gs/T/ipykernel_23536/1801721925.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_ordered['Year'][4478] = 2017
# ...

# %%
df_ordered_a = df_ordered.sort_values(by=['a'])
df_ordered_a.head(25)
# Out:
#      Blank                       Species Location        Code  Year      a  \
# 631      A           American_black_duck    Maine       44411    53  2008K
# 1271     A                 Anser_fabalis    China       Anhui   L14  2014K
# 1272     A                 Anser_fabalis    China       Anhui   L18  2014K
# 1273     A                 Anser_fabalis    China       Anhui   L22  2014K
# 1274     A                 Anser_fabalis    China       Anhui   L25  2014K
# 1275     A                 Anser_fabalis    China       Anhui    L6  2014K
# 1276     A                 Anser_fabalis    China       Anhui     L  2014K
# 1277     A                 Anser_fabalis    China       Anhui    L9  2014K
# 1278     A                 Anser_fabalis    China       Anhui   S10  2014K
# 1279     A                 Anser_fabalis    China       Anhui   S14  2014K
# 1280     A                 Anser_fabalis    China       Anhui    S2  2014K
# ...

# %%
df_ordered_a['Year'][631] = 2008

for i in range(1271, 1284):
    df_ordered_a['Year'][i] = 2014
df_ordered_a.head(25)
# Out:
# /var/folders/xy/wvlsxjjn1px0ql5dll2npm300000gs/T/ipykernel_23536/1317080872.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_ordered_a['Year'][631] = 2008
# ...

# %%
df_nz_new = df_ordered_a.drop(['a', 'b'], axis=1)
df_nz_new.head()
# Out:
#      Blank              Species Location   Code  Year  \
# 631      A  American_black_duck    Maine  44411  2008
# 1271     A        Anser_fabalis    China  Anhui  2014
# 1272     A        Anser_fabalis    China  Anhui  2014
# 1273     A        Anser_fabalis    China  Anhui  2014
# 1274     A        Anser_fabalis    China  Anhui  2014
#
#                                               gid subtype label   src  \
# 631   A/American_black_duck/Maine/44411/532/2008K    H3N8    nz  NCBI
# 1271       A/Anser_fabalis/China/Anhui/L144/2014K    H6N1    nz  NCBI
# 1272       A/Anser_fabalis/China/Anhui/L180/2014K    H6N2    nz  NCBI
# 1273       A/Anser_fabalis/China/Anhui/L221/2014K    H6N1    nz  NCBI
# 1274       A/Anser_fabalis/China/Anhui/L256/2014K    H6N1    nz  NCBI
#
#       TT_p2_Bias_HA  ...  PAAC_Xc1.L_PB2  PAAC_Xc1.A_PB2  PAAC_Xc1.P_PB2  \
# 631        0.889941  ...             0.0       33.775768             0.0
# ...

# %%
df_nz_final = df_nz_new.dropna(subset=['Year'])
df_nz_final.head()
# Out:
#      Blank              Species Location   Code  Year  \
# 631      A  American_black_duck    Maine  44411  2008
# 1271     A        Anser_fabalis    China  Anhui  2014
# 1272     A        Anser_fabalis    China  Anhui  2014
# 1273     A        Anser_fabalis    China  Anhui  2014
# 1274     A        Anser_fabalis    China  Anhui  2014
#
#                                               gid subtype label   src  \
# 631   A/American_black_duck/Maine/44411/532/2008K    H3N8    nz  NCBI
# 1271       A/Anser_fabalis/China/Anhui/L144/2014K    H6N1    nz  NCBI
# 1272       A/Anser_fabalis/China/Anhui/L180/2014K    H6N2    nz  NCBI
# 1273       A/Anser_fabalis/China/Anhui/L221/2014K    H6N1    nz  NCBI
# 1274       A/Anser_fabalis/China/Anhui/L256/2014K    H6N1    nz  NCBI
#
#       TT_p2_Bias_HA  ...  PAAC_Xc1.L_PB2  PAAC_Xc1.A_PB2  PAAC_Xc1.P_PB2  \
# 631        0.889941  ...             0.0       33.775768             0.0
# ...

# %%
df_nz_final['Species'].value_counts()
# Out:
# Species
# chicken                          3900
# mallard                          3122
# duck                             2312
# ruddy_turnstone                  1170
# blue-winged_teal                  685
#                                  ...
# African_Stonechat                   1
# wild_bird(Anas_platyrhynchos)       1
# Wild_bird                           1
# Accipiter_gentilis_schvedowi        1
# yellow_billed_duck                  1
# Name: count, Length: 482, dtype: int64
