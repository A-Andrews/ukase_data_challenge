# %%
import pandas as pd

# %%
df = pd.read_csv("../data/full_data_with_species_and_locations.csv")

# %%
df['subtype'].value_counts()
# Out:
# subtype
# H9N2     2385
# H5N1     1969
# H4N6     1397
# H3N8     1337
# H5N2     1220
#          ...
# H14N2       2
# H9N4        1
# H8N1        1
# H15N4       1
# H10N0       1
# Name: count, Length: 120, dtype: int64

# %%
df_filtered = df[df['subtype']=='H9N2']
print(df_filtered['label'].value_counts())
df_filtered.head()
# Out:
# label
# nz       2372
# hzoon      13
# Name: count, dtype: int64
#      Unnamed: 0                       Species Location  \
# 0             0  accipiter_gentilis_schvedowi  Tianjin
# 1             1             african_stonechat  Vietnam
# 43           43           american_black_duck    Maine
# 44           44           american_black_duck    Maine
# 489         489        american_oystercatcher    Chile
#
#                                                  gid  \
# 0    A/Accipiter_gentilis_schvedowi/Tianjin/22/2017M
# 1                A/African_Stonechat/Vietnam/8/2009A
# 43      A/American_black_duck/Maine/ME-Y17-326/2017M
# 44      A/American_black_duck/Maine/ME-Y17-331/2017M
# 489       A/American_oystercatcher/Chile/C1307/2015K
#
#                                               title        date subtype label  \
# 0    A/Accipiter_gentilis_schvedowi/Tianjin/22/2017  2017-06-15    H9N2    nz
# 1                A/African_Stonechat/Vietnam/8/2009  2009-11-15    H9N2    nz
# ...

# %%
df['src'].value_counts()
# Out:
# src
# NCBI      18082
# GISAID     1449
# Name: count, dtype: int64

# %%
nz_country = pd.read_csv("non_zoonotic_edited.csv")
z_country = pd.read_csv("zoonotic_with_country.csv")
# Out:
# /var/folders/xy/wvlsxjjn1px0ql5dll2npm300000gs/T/ipykernel_10283/3049836667.py:1: DtypeWarning: Columns (3,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   nz_country = pd.read_csv("non_zoonotic_edited.csv")

# %%
nz_country.head()
# Out:
#    Unnamed: 0  Species     Location Note      Country     Code  Year  \
# 0        2739  chicken  Afghanistan  NaN  Afghanistan     1207  2006
# 1        2740  chicken  Afghanistan  NaN  Afghanistan  1573-47  2006
# 2        2741  chicken  Afghanistan  NaN  Afghanistan  1573-65  2006
# 3        2742  chicken  Afghanistan  NaN  Afghanistan   1573-7  2006
# 4        2743  chicken  Afghanistan  NaN  Afghanistan  1573-92  2006
#
#                                    gid subtype label  ... PAAC_Xc1.L_PB2  \
# 0     A/chicken/Afghanistan/1207/2006C    H5N1    nz  ...              0
# 1  A/chicken/Afghanistan/1573-47/2006C    H5N1    nz  ...              0
# 2  A/chicken/Afghanistan/1573-65/2006C    H5N1    nz  ...              0
# 3   A/chicken/Afghanistan/1573-7/2006C    H5N1    nz  ...              0
# 4  A/chicken/Afghanistan/1573-92/2006C    H5N1    nz  ...              0
#
#    PAAC_Xc1.A_PB2  PAAC_Xc1.P_PB2  PAAC_Xc2.lambda3_PB2  PAAC_Xc1.F_PB2  \
# ...

# %%
nz_country_new = pd.DataFrame.copy(nz_country[['gid','Country']])
z_country_new = pd.DataFrame.copy(z_country[['gid','Country']])

# %%
countries = pd.concat([nz_country_new, z_country_new])
countries.shape
# Out:
# (18460, 2)

# %%
data_full = df.merge(countries, how = 'left', on = 'gid')
data_full.head()
# Out:
#    Unnamed: 0                       Species Location  \
# 0           0  accipiter_gentilis_schvedowi  Tianjin
# 1           1             african_stonechat  Vietnam
# 2           2         alopochen_aegyptiacus  Belgium
# 3           3         alopochen_aegyptiacus  Belgium
# 4           4         alopochen_aegyptiacus  Belgium
#
#                                                 gid  \
# 0   A/Accipiter_gentilis_schvedowi/Tianjin/22/2017M
# 1               A/African_Stonechat/Vietnam/8/2009A
# 2  A/Alopochen_aegyptiacus/Belgium/1570_B6613/2017M
# 3  A/Alopochen_aegyptiacus/Belgium/3237_B6659/2017M
# 4  A/Alopochen_aegyptiacus/Belgium/3237_B6663/2017M
#
#                                              title        date subtype label  \
# 0   A/Accipiter_gentilis_schvedowi/Tianjin/22/2017  2017-06-15    H9N2    nz
# 1               A/African_Stonechat/Vietnam/8/2009  2009-11-15    H9N2    nz
# 2  A/Alopochen_aegyptiacus/Belgium/1570_B6613/2017  2017-02-16    H1N2    nz
# ...
